# %% [markdown]
# <a href="https://colab.research.google.com/github/phuongghj123/CS331.L21/blob/main/CK331_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# clone darknet repo
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15185, done.
# remote: Total 15185 (delta 0), reused 0 (delta 0), pack-reused 15185
# Receiving objects: 100% (15185/15185), 13.59 MiB | 23.99 MiB/s, done.
# Resolving deltas: 100% (10310/10310), done.

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile
# Out:
# /content/darknet

# %%
# verify CUDA
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
# !unzip /content/drive/MyDrive/CS331/Dataset_new.zip
# Out:
# Archive:  /content/drive/MyDrive/CS331/Dataset_new.zip
#    creating: Dataset/
#   inflating: Dataset/10005.png
#   inflating: Dataset/10005.txt
#   inflating: Dataset/10011.png
#   inflating: Dataset/10011.txt
#   inflating: Dataset/10025.png
#   inflating: Dataset/10025.txt
#   inflating: Dataset/10029.png
#   inflating: Dataset/10029.txt
#   inflating: Dataset/10032.png
#   inflating: Dataset/10032.txt
#   inflating: Dataset/10037.png
#   inflating: Dataset/10037.txt
#   inflating: Dataset/10044.png
#   inflating: Dataset/10044.txt
#   inflating: Dataset/10052.png
#   inflating: Dataset/10052.txt
#   inflating: Dataset/10071.png
#   inflating: Dataset/10071.txt
#   inflating: Dataset/1008.png
#   inflating: Dataset/1008.txt
#   inflating: Dataset/10089.png
#   inflating: Dataset/10089.txt
#   inflating: Dataset/10100.png
#   inflating: Dataset/10100.txt
#   inflating: Dataset/10113.png
#   inflating: Dataset/10113.txt
#   inflating: Dataset/10125.png
# ...

# %%
import os
files = os.listdir('Dataset')
train = len(files)*80//100
valid = len(files)*20//100
i=0
with open('train.txt', 'a') as f:
  for i in range(0, train):
    if files[i].endswith('.png'):
      f.write('Dataset/'+files[i]+'\n')

with open('valid.txt', 'a') as f:
  for i in range(valid, len(files)):
    if files[i].endswith('.png'):
      f.write('Dataset/'+files[i]+'\n')

# %%
# make darknet (builds darknet so that you can then use the darknet executable file to run or train object detectors)
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
# %cd /content/darknet
# !make clean
# !make
# !chmod +x ./darknet
# Out:
# /content/darknet
# ...

# %%
# !echo classes=5 > yolo.data
# !echo train=train.txt >> yolo.data
# !echo valid=valid.txt >> yolo.data
# !echo names=yolo.names >> yolo.data
# !echo backup=backup >> yolo.data

# %%
# !echo Cam do xe > yolo.names
# !echo Cam re >> yolo.names
# !echo Giao nhau >> yolo.names
# !echo Toc do >> yolo.names
# !echo Cam nguoc chieu >> yolo.names

# %%
# !upload()
# Out:
# /bin/bash: -c: line 1: syntax error: unexpected end of file

# %%
# !./darknet detector demo /content/darknet/yolo.data /content/darknet/yolov4-custom.cfg /content/drive/MyDrive/CS331/yolov4-custom_best.weights -dont_show /content/video_test.mp4 -i 0 -out_filename /content/video_re.mp4
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
# Demo
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
# ...

# %%
# !./darknet detector test /content/darknet/yolo.data /content/darknet/yolov4-custom.cfg /content/drive/MyDrive/CS331/yolov4-custom_best.weights /content/darknet/714.png
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
# ...
